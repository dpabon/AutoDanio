# %%
from scipy import misc
from scipy import ndimage
import matplotlib.pyplot as plt
# %matplotlib inline
danio=misc.imread('/home/danne/Descargas/Primeras_fotos/prueba1.JPG')

# %%
type(danio)
danio.shape, danio.dtype
# Out:
# ((616, 1888, 3), dtype('uint8'))

# %%
plt.imshow(danio, cmap=plt.cm.gray)
linea_central=danio[270:430, 700:1500]
linea_central
# Out:
# array([[[ 76,  88,  78],
#         [ 78,  90,  80],
#         [ 77,  89,  79],
#         ...,
#         [107, 116, 111],
#         [104, 113, 108],
#         [107, 116, 111]],
#
#        [[ 77,  89,  79],
#         [ 78,  90,  80],
#         [ 78,  90,  80],
#         ...,
#         [108, 117, 112],
#         [105, 114, 109],
#         [107, 116, 111]],
#
#        [[ 82,  95,  85],
#         [ 79,  92,  82],
#         [ 70,  83,  73],
#         ...,
#         [107, 116, 111],
#         [109, 118, 113],
#         [105, 114, 109]],
#
#        ...,
#        [[115, 122, 114],
#         [112, 119, 111],
#         [110, 117, 109],
#         ...,
#         [ 97, 104,  97],
#         [ 99, 106,  99],
#         [ 97, 104,  97]],
#
#        [[111, 118, 110],
#         [110, 117, 109],
#         [110, 117, 109],
#         ...,
#         [ 94, 101,  94],
#         [ 92,  99,  92],
#         [ 92,  99,  92]],
#
#        [[112, 119, 111],
#         [110, 117, 109],
#         [111, 118, 110],
#         ...,
#         [ 91,  98,  91],
#         [ 82,  89,  82],
#         [ 82,  89,  82]]], dtype=uint8)

# %%
linea_central.mean()
linea_central.min(), linea_central.max()
# Out:
# (29, 133)

# %%
plt.imshow(linea_central, cmap=plt.cm.gray)

# %%
plt.imshow(linea_central, cmap=plt.cm.gray, interpolation='nearest' )

# %%
rotate_danio = ndimage.rotate(linea_central, -6.5)
plt.imshow(rotate_danio)

# %%
dx, dy, dz = linea_central.shape

# %%
danio.shape
# Out:
# (616, 1888, 3)
